# %%
from objects import *

# %%
sd = StockData()

# %%
stock_list = ['SQ','FIS','FISV','ADP','PAYX','GPN']  #list of peers

# %%
sd.get_beta_data(stock_list)

# %%
sd.plot_relative_return()

# %%
sd.dataset
# Out:
#           index    adjclose  pct_change  log_return ticker       ADP  \
# 0    2009-01-05   70.829811   -0.001184   -0.001184    SPY -0.010146
# 1    2009-01-06   71.302818    0.006678    0.006656    SPY  0.020250
# 2    2009-01-07   69.166855   -0.029956   -0.030414    SPY -0.017153
# 3    2009-01-08   69.449081    0.004080    0.004072    SPY  0.012466
# 4    2009-01-09   67.961540   -0.021419   -0.021652    SPY -0.049249
# ...         ...         ...         ...         ...    ...       ...
# 3548 2023-02-08  410.649994   -0.010935   -0.010995    SPY -0.012303
# 3549 2023-02-09  407.089996   -0.008669   -0.008707    SPY -0.000312
# 3550 2023-02-10  408.040009    0.002334    0.002331    SPY  0.008530
# 3551 2023-02-13  412.829987    0.011739    0.011671    SPY  0.006820
# 3552 2023-02-14  412.640015   -0.000460   -0.000460    SPY -0.012183
#
#            FIS      FISV       GPN      PAYX        SQ
# 0     0.005865 -0.001309 -0.019894 -0.019302       NaN
# 1     0.015743  0.013634  0.038209 -0.000757       NaN
# 2    -0.023536 -0.036213  0.004888 -0.012121       NaN
# 3     0.008818  0.000805  0.008011  0.003834       NaN
# 4    -0.019813 -0.032180  0.007380 -0.033231       NaN
# ...        ...       ...       ...       ...       ...
# 3548 -0.024987  0.005378 -0.023103 -0.018364 -0.024645
# 3549  0.008042  0.005177  0.000090 -0.010267 -0.061013
# 3550  0.020014 -0.007382  0.055894  0.004132 -0.012470
# 3551 -0.125017  0.007004 -0.026298  0.011294  0.021135
# 3552  0.027424 -0.003778  0.012197 -0.013592  0.025775
#
# [3553 rows x 11 columns]

# %%
df_corr = sd.get_cross_correlations(stock_list)

# %%
df_corr
# Out:
#           index    FIS_SQ   FISV_SQ    ADP_SQ   PAYX_SQ    GPN_SQ  FISV_FIS  \
# 0    2009-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 1    2009-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2    2009-01-07       NaN       NaN       NaN       NaN       NaN       NaN
# 3    2009-01-08       NaN       NaN       NaN       NaN       NaN       NaN
# 4    2009-01-09       NaN       NaN       NaN       NaN       NaN       NaN
# ...         ...       ...       ...       ...       ...       ...       ...
# 3548 2023-02-08  0.701705  0.494372  0.438046  0.607417  0.707881  0.556207
# 3549 2023-02-09  0.672875  0.501986  0.474476  0.625028  0.692611  0.568683
# 3550 2023-02-10  0.661062  0.501694  0.472869  0.624897  0.629061  0.553528
# 3551 2023-02-13  0.494706  0.506981  0.466344  0.628542  0.623876  0.416519
# 3552 2023-02-14  0.484858  0.500752  0.468856  0.613172  0.611238  0.404205
#
#        ADP_FIS  PAYX_FIS   GPN_FIS  ADP_FISV  PAYX_FISV  GPN_FISV  PAYX_ADP  \
# 0          NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 1          NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 2          NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 3          NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 4          NaN       NaN       NaN       NaN        NaN       NaN       NaN
# ...        ...       ...       ...       ...        ...       ...       ...
# 3548  0.458684  0.583806  0.777604  0.551632   0.571573  0.686450  0.875077
# 3549  0.488087  0.585469  0.774741  0.550171   0.568058  0.695635  0.880388
# 3550  0.499123  0.590750  0.756815  0.543814   0.564743  0.620841  0.880137
# 3551  0.361499  0.407269  0.698401  0.547646   0.565268  0.605792  0.882820
# 3552  0.354711  0.383057  0.690566  0.551232   0.565286  0.603874  0.888066
#
#        GPN_ADP  GPN_PAYX   60_corr
# 0          NaN       NaN       NaN
# 1          NaN       NaN       NaN
# 2          NaN       NaN       NaN
# 3          NaN       NaN       NaN
# 4          NaN       NaN       NaN
# ...        ...       ...       ...
# 3548  0.493425  0.631145  0.609002
# 3549  0.517022  0.634289  0.615301
# 3550  0.516927  0.611644  0.601860
# 3551  0.508196  0.585363  0.553281
# 3552  0.515491  0.572938  0.547220
#
# [3553 rows x 17 columns]

# %%
import matplotlib.pylab as plt
plt.rcParams['figure.dpi'] = 200
sd.plot_cross_correlations()
