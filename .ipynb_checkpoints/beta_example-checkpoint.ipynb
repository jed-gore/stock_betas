# %%
from objects import *

# %%
sd = StockData()

# %%
stock_list = ['SQ','FIS','FISV','ADP','PAYX','GPN']  #list of peers
sd.get_beta_data(stock_list)

# %%
sd.betas_dict
# Out:
# {'ADP': 0.9397094977022615,
#  'FIS': 0.9663274869655246,
#  'PAYX': 0.9684034430635797,
#  'FISV': 0.9987560018671606,
#  'GPN': 1.113583626401711,
#  'SQ': 1.9018589243270052}

# %%
sd.plot_relative_return()

# %%
betas_list = ['TLT','MSTR','SPY','V','GPN','FXI','USO','AMZN']

sd.get_r2_data(betas_list,'SQ')

# %%
sd.r2_data
# Out:
#   TICKER     R2_60     R2_90    R2_252
# 0   AMZN  0.498312  0.536655  0.495908
# 1    FXI  0.155037  0.244881  0.253014
# 2    GPN  0.389371  0.326744  0.313996
# 3   MSTR  0.476749  0.391025  0.502161
# 4    SPY  0.680563  0.683742  0.589338
# 5    TLT  0.024347  0.055282  0.014203
# 6    USO  0.085049  0.093250  0.002251
# 7      V  0.418427  0.435578  0.360343

# %%
sd.plot_r2_data('SQ')
